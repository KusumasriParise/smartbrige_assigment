# %% [markdown]
# Basic Python

# %% [markdown]
# NumPy

# %%
import numpy as np
array=np.random.random((3,3))
print("array:",array)
mean=np.mean(array)
print("mean:",mean)
median=np.median(array)
print("median:",median)
std_dev=np.std(array)
print("std_dev:",std_dev)
# Out:
# array: [[0.86736863 0.17834584 0.54579801]
#  [0.09893846 0.82803274 0.12001649]
#  [0.03301983 0.97732977 0.40269909]]
# mean: 0.45017209481620885
# median: 0.40269908589211156
# std_dev: 0.3474347489805047

# %%
m1=np.array([[4,6],[8,10]])
m2=np.array([[2,4],[6,8]])
result=np.dot(m1,m2)
print("multiplication:",result)
# Out:
# multiplication: [[ 44  64]
#  [ 76 112]]

# %% [markdown]
# Pandas

# %%
/content/drive/MyDrive/mtcars.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-61487f040962> in <cell line: 1>()
# ----> 1 content/drive/MyDrive/mtcars.csv()
#
# NameError: name 'content' is not defined

# %%
import pandas as pd
df=pd.read_csv('/content/mtcars.csv')
df.head()
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df[(df.hp>80)&(df.gear>3) ]
# Out:
#              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 8         Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9         Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# 10       Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# 26   Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import numpy as np

# %% [markdown]
# Line plot

# %%
x=np.linspace(-10,10,400)
y=x**2
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y=x^2')
# Out:
# Text(0.5, 1.0, 'Plot of y=x^2')

# %% [markdown]
# BAR GRAPH

# %%
classes=['class A','class B','class C','class D','class E']
students=[25,23,15,10,30]
plt.bar(classes,students)
plt.xlabel('classes')
plt.ylabel('Number of students')
plt.title('Number of Students in Different Classes')
# Out:
# Text(0.5, 1.0, 'Number of Students in Different Classes')

# %% [markdown]
# **Histogram**

# %%
tips=sns.load_dataset("tips")
sns.histplot(tips)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Heat Map

# %%
data=np.random.rand(10, 10)
correlation_matrix=np.corrcoef(data)
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >
